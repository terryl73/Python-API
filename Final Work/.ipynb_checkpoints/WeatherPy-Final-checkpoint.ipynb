# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 652

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import json 
import requests


#target_url = "http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=8f0b0efa2c2a1bd9fba87e03fc58338d"

api_key = '8f0b0efa2c2a1bd9fba87e03fc58338d'
WeatherData = {"City":["ABC","XYZ"],"Cloudiness":[1,2], "Country":["A","B"],"Date":[1000000,1000001],"Humidity":[1,2],
               "Lat":[11.1,22.2],"Lng":[11.1,22.2],"Max Temp":[100,200],"Wind Speed":[10,20]}
#AddRow = {"City":[],"Cloudiness":[],"Country":[],"Date":[],"Humidity":[],"Lat":[],"Lng":[],"Max Temp":[],"Wind Speed":[]}

WeatherDF = pd.DataFrame(WeatherData)

for target_city in cities:
    target_url = ('http://api.openweathermap.org/data/2.5/weather?q={0}&APPID={1}').format(target_city, api_key) 
    
    try:
        response = requests.get(target_url)
        Data_json = response.json()
#Assign Json to DataFrame
        print(target_city + "# " + str(Data_json["id"]) + " is being loaded.")
        WeatherData["City"] = Data_json["name"]
        WeatherData["Cloudiness"] = Data_json["clouds"]["all"]
        WeatherData["Country"] = Data_json["sys"]["country"]
        WeatherData["Date"] = Data_json["dt"]
        WeatherData["Humidity"] = Data_json["main"]["humidity"]
        WeatherData["Lat"] = Data_json["coord"]["lat"]
        WeatherData["Lng"] = Data_json["coord"]["lon"]
        WeatherData["Max Temp"] = Data_json["main"]["temp_max"]-273.15
        WeatherData["Wind Speed"] = Data_json["wind"]["speed"]
        WeatherDF = WeatherDF.append(WeatherData, ignore_index=True)
    except KeyError:
        print(target_city + " is not available.")
    
#Change C to F
WeatherDF["Max Temp"] = WeatherDF["Max Temp"] * 1.8 + 32

#Change m/s to mph
WeatherDF["Wind Speed"] = WeatherDF["Wind Speed"] * 2.23693629

WeatherDF = WeatherDF.drop([0,1])
WeatherDF.reset_index(inplace = True, drop=True)

print("Download complete!")

WeatherDF.to_csv("Global_Weather.csv")
# Out:
# qaanaaq# 3831208 is being loaded.
# cabimas# 3647651 is being loaded.
# punta arenas# 3874787 is being loaded.
# rikitea# 4030556 is being loaded.
# kota belud# 1736660 is being loaded.
# pedernales# 3653307 is being loaded.
# waipawa# 2185329 is being loaded.
# vila franca do campo# 3372472 is being loaded.
# george town# 1735106 is being loaded.
# rio verde de mato grosso# 3451051 is being loaded.
# yuancheng is not available.
# sorland# 3137469 is being loaded.
# alice springs# 2077895 is being loaded.
# saskylakh# 2017155 is being loaded.
# makakilo city# 5850554 is being loaded.
# vaini# 1273574 is being loaded.
# bad kreuznach# 2953416 is being loaded.
# colac# 2171069 is being loaded.
# bluff# 2175403 is being loaded.
# castro# 3896218 is being loaded.
# taolanaro is not available.
# upernavik# 3418910 is being loaded.
# albany# 5106834 is being loaded.
# bredasdorp# 1015776 is being loaded.
# yellowknife# 6185377 is being loaded.
# abu dhabi# 292968 is being loaded.
# ushuaia# 3833367 is being loaded.
# barentsburg is not available.
# ondorhaan is not available.
# talnakh# 1490256 is being loaded.
# jamestown# 2069194 is being loaded.
# mataura# 6201424 is being loaded.
# lamu# 1623890 is being loaded.
# chifeng# 2038067 is being loaded.
# port alfred# 964432 is being loaded.
# ravar# 118704 is being loaded.
# bengkulu is not available.
# tiksi# 2015306 is being loaded.
# busselton# 2075265 is being loaded.
# auki# 2339937 is being loaded.
# wasilla# 5877641 is being loaded.
# torbay# 6167817 is being loaded.
# hilo# 5855927 is being loaded.
# avarua# 4035715 is being loaded.
# quimper# 2984701 is being loaded.
# emba# 146639 is being loaded.
# tanshui is not available.
# basse-pointe# 3571097 is being loaded.
# hermanus# 3366880 is being loaded.
# bilma# 2446796 is being loaded.
# new norfolk# 2155415 is being loaded.
# coihaique# 3894426 is being loaded.
# codrington# 2160063 is being loaded.
# cazaje is not available.
# fort-shevchenko# 609906 is being loaded.
# grindavik# 3416888 is being loaded.
# ust-omchug# 2120047 is being loaded.
# ginda# 1253628 is being loaded.
# alexandria# 4314550 is being loaded.
# aklavik# 5882953 is being loaded.
# nikolskoye# 546105 is being loaded.
# tautira# 4033557 is being loaded.
# atuona# 4020109 is being loaded.
# arraial do cabo# 3471451 is being loaded.
# deputatskiy# 2028164 is being loaded.
# kununurra# 2068110 is being loaded.
# khatanga# 2022572 is being loaded.
# beyneu# 610298 is being loaded.
# carnarvon# 1014034 is being loaded.
# kaniama# 214389 is being loaded.
# saint-philippe# 6138908 is being loaded.
# angoche# 1052944 is being loaded.
# cherskiy# 2126199 is being loaded.
# ust-tsilma# 477940 is being loaded.
# noumea# 2139521 is being loaded.
# dikson# 1507390 is being loaded.
# butaritari# 2110227 is being loaded.
# sarkand# 1519691 is being loaded.
# villazon is not available.
# cape town# 3369157 is being loaded.
# beisfjord# 3144987 is being loaded.
# nguiu is not available.
# belaya gora# 2126785 is being loaded.
# taoudenni# 2450173 is being loaded.
# ruzomberok# 3057789 is being loaded.
# ancud# 3899695 is being loaded.
# takoradi# 2294915 is being loaded.
# hithadhoo# 1282256 is being loaded.
# bokspits is not available.
# isla mujeres# 3526756 is being loaded.
# galesong# 1644605 is being loaded.
# huangmei# 1807339 is being loaded.
# constitucion# 4011743 is being loaded.
# marathopolis is not available.
# araceli# 1730272 is being loaded.
# port elizabeth# 4501427 is being loaded.
# doctor pedro p. pena is not available.
# kodiak# 4407665 is being loaded.
# nanortalik# 3421765 is being loaded.
# mitsamiouli# 921786 is being loaded.
# miri# 2347470 is being loaded.
# obluche is not available.
# salinas# 5391295 is being loaded.
# petropavlovsk-kamchatskiy# 2122104 is being loaded.
# loiza# 4566022 is being loaded.
# magaria# 2441482 is being loaded.
# chokurdakh# 2126123 is being loaded.
# nuuk# 3421319 is being loaded.
# conde# 3465713 is being loaded.
# fasa# 134721 is being loaded.
# mandalgovi# 2030065 is being loaded.
# berlevag# 780687 is being loaded.
# krasnaya poyma# 542637 is being loaded.
# ribeira grande# 3372707 is being loaded.
# pevek# 2122090 is being loaded.
# sakakah is not available.
# los llanos de aridane# 2514651 is being loaded.
# gravdal# 3147822 is being loaded.
# stromness# 5914857 is being loaded.
# touros# 3386213 is being loaded.
# west bay# 2654726 is being loaded.
# dunedin# 2191562 is being loaded.
# bambous virieux# 1106677 is being loaded.
# bristol# 2654675 is being loaded.
# esperance# 3573739 is being loaded.
# bethel# 5880568 is being loaded.
# jatai# 1270260 is being loaded.
# port hardy# 6111862 is being loaded.
# san patricio# 3437029 is being loaded.
# bardiyah is not available.
# kaitangata# 2208248 is being loaded.
# barrow# 3833859 is being loaded.
# sao jose de piranhas# 3388442 is being loaded.
# vostok# 2013279 is being loaded.
# terrace# 6162949 is being loaded.
# flinders# 6255012 is being loaded.
# nizhneyansk is not available.
# pemberton# 2063604 is being loaded.
# ridgecrest# 5387494 is being loaded.
# jiexiu# 1805833 is being loaded.
# kurri kurri# 2160922 is being loaded.
# veinticinco de mayo# 3427537 is being loaded.
# east london# 1006984 is being loaded.
# cuiluan# 2033413 is being loaded.
# sentyabrskiy is not available.
# norman wells# 6089245 is being loaded.
# north platte# 5697939 is being loaded.
# sheksna# 495062 is being loaded.
# wa is not available.
# letlhakeng# 933534 is being loaded.
# klaksvik# 2618795 is being loaded.
# tasiilaq# 3424607 is being loaded.
# belmonte# 8010472 is being loaded.
# puerto ayora# 3652764 is being loaded.
# tumannyy is not available.
# san quintin# 1688687 is being loaded.
# kantang# 1153072 is being loaded.
# araouane# 2460954 is being loaded.
# yerbogachen# 2012956 is being loaded.
# belushya guba is not available.
# marquette# 5000947 is being loaded.
# pangkalanbuun# 1632694 is being loaded.
# umzimvubu is not available.
# carutapera# 3402648 is being loaded.
# mugumu# 152663 is being loaded.
# gjirokaster# 783148 is being loaded.
# ilulissat# 3423146 is being loaded.
# olinda# 3650121 is being loaded.
# palmas# 3474574 is being loaded.
# maha sarakham# 1608900 is being loaded.
# kapaa# 5848280 is being loaded.
# alakurtti# 583472 is being loaded.
# aberdeen# 5225857 is being loaded.
# buqayq is not available.
# naftah is not available.
# hasaki# 2112802 is being loaded.
# leningradskiy# 2123814 is being loaded.
# oyem# 2396646 is being loaded.
# illoqqortoormiut is not available.
# lebu# 344979 is being loaded.
# satitoa is not available.
# isangel# 2136825 is being loaded.
# cayenne# 3382160 is being loaded.
# souillac# 3026644 is being loaded.
# louisbourg is not available.
# magadan# 2123628 is being loaded.
# lagoa# 2267254 is being loaded.
# kavieng# 2094342 is being loaded.
# tilichiki# 2120591 is being loaded.
# eenhana# 3357804 is being loaded.
# port-de-paix is not available.
# longyearbyen# 2729907 is being loaded.
# adrar# 2508813 is being loaded.
# gizo# 6693679 is being loaded.
# khandyga# 2022773 is being loaded.
# khanpur# 1174167 is being loaded.
# college# 5859699 is being loaded.
# khristoforovo is not available.
# sesheke# 898905 is being loaded.
# beloha# 1067565 is being loaded.
# wilmington# 4145381 is being loaded.
# saint-pierre# 2995603 is being loaded.
# micheweni# 153955 is being loaded.
# soubre# 2598243 is being loaded.
# teguldet# 1489822 is being loaded.
# pocatello# 5604045 is being loaded.
# fairbanks# 5861897 is being loaded.
# dickinson# 5688789 is being loaded.
# ostersund# 2685750 is being loaded.
# ostroh# 698232 is being loaded.
# hobart# 2163355 is being loaded.
# ust-kuyga# 2013921 is being loaded.
# rojhan# 1166819 is being loaded.
# okoneshnikovo# 1496329 is being loaded.
# tuktoyaktuk# 6170031 is being loaded.
# alofi# 4036284 is being loaded.
# concepcion del oro# 4013039 is being loaded.
# georgetown# 3378644 is being loaded.
# tingrela is not available.
# byron bay# 2172880 is being loaded.
# bac lieu is not available.
# hay river# 5972762 is being loaded.
# marawi# 1701054 is being loaded.
# council bluffs# 4852832 is being loaded.
# kitakata# 1859319 is being loaded.
# nizhniy tsasuchey# 2019118 is being loaded.
# oriximina# 3393471 is being loaded.
# shaoyang# 1799462 is being loaded.
# mar del plata# 3863379 is being loaded.
# namibe# 3347019 is being loaded.
# yulara# 6355222 is being loaded.
# kinshasa# 2314302 is being loaded.
# pacific grove# 5380437 is being loaded.
# cheremukhovo# 466423 is being loaded.
# komsomolskiy# 1486910 is being loaded.
# buckeye# 5287262 is being loaded.
# uwayl is not available.
# vila velha# 6320062 is being loaded.
# husavik# 5961417 is being loaded.
# marcona is not available.
# tsihombe is not available.
# abu road# 1279394 is being loaded.
# sandwick# 2640416 is being loaded.
# praia da vitoria# 3372760 is being loaded.
# saldanha# 2737599 is being loaded.
# grand river south east is not available.
# ponta do sol# 3453439 is being loaded.
# santo tomas# 1687513 is being loaded.
# montepuez# 1037125 is being loaded.
# kavaratti# 1267390 is being loaded.
# mahibadhoo# 1337605 is being loaded.
# bilibino# 2126682 is being loaded.
# sabha# 2212775 is being loaded.
# fare# 4034496 is being loaded.
# itoman# 1861280 is being loaded.
# healesville# 2163701 is being loaded.
# santiago# 3871336 is being loaded.
# antropovo# 581459 is being loaded.
# muros# 3115824 is being loaded.
# faanui# 4034551 is being loaded.
# maceio# 3395981 is being loaded.
# correntina# 3465373 is being loaded.
# lakselv# 779082 is being loaded.
# kashi is not available.
# warqla is not available.
# sosnovo-ozerskoye# 2016216 is being loaded.
# dongsheng# 1788268 is being loaded.
# parana# 3663516 is being loaded.
# ugoofaaru# 1337619 is being loaded.
# toyooka# 1849831 is being loaded.
# lazaro cardenas# 3996234 is being loaded.
# geraldton# 5960603 is being loaded.
# adelaide# 2078025 is being loaded.
# srednekolymsk# 2121025 is being loaded.
# gat# 2249901 is being loaded.
# montauban# 6454798 is being loaded.
# levokumskoye# 535438 is being loaded.
# naryshkino# 523382 is being loaded.
# half moon bay# 5354943 is being loaded.
# moose factory# 6078372 is being loaded.
# solovetskiy is not available.
# waddan# 2209055 is being loaded.
# wageningen# 2745088 is being loaded.
# teya# 3526662 is being loaded.
# quibdo# 3671116 is being loaded.
# nizwa# 286987 is being loaded.
# fort nelson# 5955902 is being loaded.
# horsham# 2163055 is being loaded.
# airai# 1651810 is being loaded.
# zhigansk# 2012530 is being loaded.
# sinnamary# 3380290 is being loaded.
# yaan# 2338660 is being loaded.
# parrsboro# 6098717 is being loaded.
# palmas bellas# 3703523 is being loaded.
# limon# 5428504 is being loaded.
# tabas# 113659 is being loaded.
# quatre cocos# 1106643 is being loaded.
# gayeri# 2360541 is being loaded.
# skalistyy is not available.
# armizonskoye# 1511382 is being loaded.
# bandarbeyla# 64814 is being loaded.
# thompson# 6165406 is being loaded.
# cedar city# 5536630 is being loaded.
# rawlins# 5836068 is being loaded.
# manicore# 3663503 is being loaded.
# berbera is not available.
# batagay-alyta# 2027042 is being loaded.
# macusani# 3935624 is being loaded.
# nola# 2383827 is being loaded.
# pisco# 3932145 is being loaded.
# kozhva# 543246 is being loaded.
# clyde river# 5924351 is being loaded.
# samalaeulu is not available.
# skjervoy# 777682 is being loaded.
# mestec kralove# 3070822 is being loaded.
# itarema# 3393692 is being loaded.
# hambantota# 1244926 is being loaded.
# msanga# 153046 is being loaded.
# mahebourg# 934322 is being loaded.
# tutoia# 3385899 is being loaded.
# camacha# 2270385 is being loaded.
# tosno# 481964 is being loaded.
# kudahuvadhoo# 1337607 is being loaded.
# luang prabang# 1655559 is being loaded.
# rundu# 3353383 is being loaded.
# barcelona# 3128760 is being loaded.
# saleaula is not available.
# edd# 338345 is being loaded.
# egvekinot# 4031742 is being loaded.
# goderich# 5962442 is being loaded.
# taebla# 592225 is being loaded.
# kalga# 2023286 is being loaded.
# acapetahua is not available.
# cabo san lucas# 3985710 is being loaded.
# victoria# 1733782 is being loaded.
# skibbereen# 2961459 is being loaded.
# pangnirtung# 6096551 is being loaded.
# maridi is not available.
# wagar# 4069458 is being loaded.
# corpus christi# 4683416 is being loaded.
# yomitan is not available.
# kaeo# 2189343 is being loaded.
# atikokan# 5888001 is being loaded.
# mys shmidta is not available.
# amderma is not available.
# matagami# 2335713 is being loaded.
# opuwo# 3354077 is being loaded.
# jasper# 4069659 is being loaded.
# san cristobal# 3652462 is being loaded.
# dubenskiy is not available.
# poum# 787487 is being loaded.
# show low# 5314245 is being loaded.
# san carlos de bariloche# 7647007 is being loaded.
# saint george# 262462 is being loaded.
# arrecife is not available.
# kruisfontein# 986717 is being loaded.
# princeton# 4906818 is being loaded.
# lorengau# 2092164 is being loaded.
# mombetsu# 2129163 is being loaded.
# llanelli# 2644100 is being loaded.
# nacala# 1035025 is being loaded.
# bermejo# 3923154 is being loaded.
# westport# 2960970 is being loaded.
# coahuayana# 3981460 is being loaded.
# mongo# 240498 is being loaded.
# lisakovsk# 1521315 is being loaded.
# nhulunbuy# 2064735 is being loaded.
# laguna# 4013704 is being loaded.
# acarau is not available.
# tezu# 1254709 is being loaded.
# tsienyane is not available.
# san vicente# 3583178 is being loaded.
# robertsport# 2274275 is being loaded.
# guerrero negro# 4021858 is being loaded.
# curuguaty# 3437088 is being loaded.
# tasbuget is not available.
# phalombe# 924206 is being loaded.
# ossora# 2122389 is being loaded.
# namatanai# 2090021 is being loaded.
# suvorov# 485888 is being loaded.
# margate# 2158744 is being loaded.
# nioro# 2413070 is being loaded.
# necochea# 3430443 is being loaded.
# san andres# 1690438 is being loaded.
# omboue# 2396853 is being loaded.
# kahului# 5847411 is being loaded.
# flin flon# 5954718 is being loaded.
# basoko# 219414 is being loaded.
# caledon# 3369179 is being loaded.
# lompoc# 5367788 is being loaded.
# cidreira# 3466165 is being loaded.
# nguru# 2328952 is being loaded.
# faya# 110690 is being loaded.
# adwa# 344420 is being loaded.
# vaijapur# 1253545 is being loaded.
# aquiraz# 3407407 is being loaded.
# walvis bay# 3359638 is being loaded.
# grand centre is not available.
# lolua is not available.
# itaituba# 3397967 is being loaded.
# goycay is not available.
# zlitan# 2208485 is being loaded.
# burnie# 2173125 is being loaded.
# luderitz# 3355672 is being loaded.
# coari# 3664539 is being loaded.
# tuatapere# 2180815 is being loaded.
# cockburn town# 3576994 is being loaded.
# sioux lookout# 6148373 is being loaded.
# talsi# 454970 is being loaded.
# gloucester# 2648404 is being loaded.
# lashma# 536857 is being loaded.
# mubende# 228971 is being loaded.
# terney# 2015352 is being loaded.
# balsas# 3406545 is being loaded.
# shingu# 1847947 is being loaded.
# namanyere# 151986 is being loaded.
# damara# 2387435 is being loaded.
# baruun-urt# 2032614 is being loaded.
# axim# 2303611 is being loaded.
# jiddah is not available.
# sola# 3137942 is being loaded.
# horizontina# 3461659 is being loaded.
# ostrovnoy# 556268 is being loaded.
# suixi# 1793889 is being loaded.
# vangaindrano# 1054329 is being loaded.
# chilca# 3934055 is being loaded.
# anito# 1730622 is being loaded.
# mbuji-mayi# 209228 is being loaded.
# bolshoye selo# 573338 is being loaded.
# carauari# 3664659 is being loaded.
# smithers# 6149996 is being loaded.
# ukiah# 5404476 is being loaded.
# sorong# 1626542 is being loaded.
# hofn# 2630299 is being loaded.
# mayor pablo lagerenza# 3867427 is being loaded.
# nouadhibou# 2377457 is being loaded.
# wyndham# 2639447 is being loaded.
# susurluk# 300058 is being loaded.
# nome# 4732862 is being loaded.
# mitu# 117392 is being loaded.
# tessalit# 2449893 is being loaded.
# strezhevoy# 1490796 is being loaded.
# port-gentil# 2396518 is being loaded.
# paka# 3190586 is being loaded.
# sitka# 4267710 is being loaded.
# at-bashi# 1528796 is being loaded.
# boyolangu# 1648082 is being loaded.
# sikeston# 4408672 is being loaded.
# victoria point# 2145214 is being loaded.
# dudinka# 1507116 is being loaded.
# kambarka# 553835 is being loaded.
# rawson# 3839307 is being loaded.
# kirakira# 2178753 is being loaded.
# ballina# 2966778 is being loaded.
# samusu is not available.
# taksimo# 2015701 is being loaded.
# angol# 3899629 is being loaded.
# uarini# 3661756 is being loaded.
# onufriyivka# 698479 is being loaded.
# karkaralinsk is not available.
# bolshoy tsaryn is not available.
# hobyo# 57000 is being loaded.
# bukama# 217834 is being loaded.
# mana# 789988 is being loaded.
# gurgan is not available.
# oskarshamn# 2686162 is being loaded.
# charlestown# 5221384 is being loaded.
# coquimbo# 3893629 is being loaded.
# santo estevao# 3449467 is being loaded.
# luganville# 2136150 is being loaded.
# kihei# 5849297 is being loaded.
# provideniya# 4031574 is being loaded.
# bari is not available.
# mutsamudu is not available.
# jalu# 86049 is being loaded.
# vestmannaeyjar# 3412093 is being loaded.
# verkhnyaya inta# 1487332 is being loaded.
# nantucket# 4944903 is being loaded.
# bogorodskoye# 2126638 is being loaded.
# el balyana is not available.
# chimbote# 3698304 is being loaded.
# cooma# 2170577 is being loaded.
# hamilton# 5969785 is being loaded.
# jaramana is not available.
# kyabram# 2160910 is being loaded.
# attawapiskat is not available.
# tarakan# 1624725 is being loaded.
# baker city# 5712169 is being loaded.
# oussouye# 2246901 is being loaded.
# yurkivka# 691016 is being loaded.
# havelock# 4470244 is being loaded.
# tungkang is not available.
# aitape# 2101169 is being loaded.
# los algarrobos# 3654533 is being loaded.
# tabou# 2281120 is being loaded.
# furano# 2128147 is being loaded.
# gainesville# 4156404 is being loaded.
# gurskoye is not available.
# repatriacion# 3437197 is being loaded.
# padang# 1633419 is being loaded.
# plettenberg bay# 964712 is being loaded.
# kayerkan# 1497337 is being loaded.
# bolungarvik is not available.
# vardo# 4372777 is being loaded.
# dalby# 2169535 is being loaded.
# oktyabrskoye# 1511846 is being loaded.
# severo-kurilsk# 2121385 is being loaded.
# shache# 1280037 is being loaded.
# lakes entrance# 2160735 is being loaded.
# broome# 2656067 is being loaded.
# lenggries# 6556127 is being loaded.
# wahran is not available.
# yumen# 1528998 is being loaded.
# ust-ordynskiy# 2013894 is being loaded.
# kloulklubed# 7671223 is being loaded.
# morondava# 1058381 is being loaded.
# vaitupu is not available.
# kuching# 1735634 is being loaded.
# karaul is not available.
# cabra# 2520645 is being loaded.
# sungaipenuh# 1625929 is being loaded.
# fauske# 3157781 is being loaded.
# parabel# 1495586 is being loaded.
# arroyo# 5208292 is being loaded.
# kulunda# 1501460 is being loaded.
# carovigno# 3180462 is being loaded.
# taburi is not available.
# awjilah# 88533 is being loaded.
# gijon# 3121424 is being loaded.
# chapayevka# 2122104 is being loaded.
# kajaani# 654901 is being loaded.
# maldonado# 3441894 is being loaded.
# bonfim# 3451126 is being loaded.
# kasungu# 928534 is being loaded.
# mayenne# 2994935 is being loaded.
# shimanovsk# 2016701 is being loaded.
# fortuna# 2517679 is being loaded.
# kousseri is not available.
# solton# 1491428 is being loaded.
# borogontsy# 2026160 is being loaded.
# sao filipe# 3374210 is being loaded.
# tshane# 933726 is being loaded.
# ahuimanu# 5856516 is being loaded.
# ercis# 315530 is being loaded.
# harwich# 4939004 is being loaded.
# saint-augustin# 3031582 is being loaded.
# podor# 2245170 is being loaded.
# samarai# 2132606 is being loaded.
# the valley# 3573374 is being loaded.
# nevsehir# 303831 is being loaded.
# morki# 525262 is being loaded.
# maragogi# 3395458 is being loaded.
# lusambo# 210379 is being loaded.
# autun# 3035883 is being loaded.
# chuy# 3443061 is being loaded.
# yatou# 2225940 is being loaded.
# nakamura# 1856057 is being loaded.
# blagoveshchenka# 1509999 is being loaded.
# lurgan# 2641364 is being loaded.
# ulladulla# 2145554 is being loaded.
# lake havasu city# 5301388 is being loaded.
# alyangula# 2079582 is being loaded.
# japura# 1642773 is being loaded.
# khasan# 2039557 is being loaded.
# shenjiamen# 1795632 is being loaded.
# monaghan# 2962568 is being loaded.
# el retorno# 3792387 is being loaded.
# abu kamal# 174448 is being loaded.
# baillif# 3579761 is being loaded.
# kuopio# 650225 is being loaded.
# nueve de julio# 3842882 is being loaded.
# nago# 3172402 is being loaded.
# matara# 3948642 is being loaded.
# bismarck# 5688025 is being loaded.
# grand gaube# 934479 is being loaded.
# mendahara is not available.
# donghai# 1549542 is being loaded.
# homer# 5864145 is being loaded.
# keuruu# 652977 is being loaded.
# laiagam is not available.
# bafq# 142255 is being loaded.
# laguna de perlas# 3618522 is being loaded.
# severo-yeniseyskiy# 1492566 is being loaded.
# alepe# 2293045 is being loaded.
# ruwi# 287286 is being loaded.
# hrinova# 3059870 is being loaded.
# olafsvik is not available.
# banfora# 2362909 is being loaded.
# lyuban# 625721 is being loaded.
# shalinskoye# 1492466 is being loaded.
# alta floresta# 6316343 is being loaded.
# changli# 1793900 is being loaded.
# miraflores# 3674735 is being loaded.
# marzuq# 72181 is being loaded.
# tual# 1623197 is being loaded.
# nyurba# 2018735 is being loaded.
# santa rosa# 3835994 is being loaded.
# beringovskiy# 2126710 is being loaded.
# dalvik# 2702977 is being loaded.
# ginir# 336454 is being loaded.
# pacifica# 5380420 is being loaded.
# harrisonburg# 4763231 is being loaded.
# schattdorf# 2658749 is being loaded.
# great falls# 5655240 is being loaded.
# kodinsk# 1503037 is being loaded.
# pinega# 509483 is being loaded.
# davila# 1715335 is being loaded.
# katsuura# 1865309 is being loaded.
# acapulco# 3533462 is being loaded.
# port hawkesbury# 6111867 is being loaded.
# le pradet# 3010153 is being loaded.
# ust-nera# 2120048 is being loaded.
# camudmud# 1958759 is being loaded.
# haines junction# 5969025 is being loaded.
# mullaitivu is not available.
# kisangani# 212730 is being loaded.
# sistranda# 3139597 is being loaded.
# yarqa# 245939 is being loaded.
# calbuco# 3897334 is being loaded.
# kawalu# 1640902 is being loaded.
# kayes# 2455518 is being loaded.
# labutta is not available.
# molteno# 974719 is being loaded.
# sibu# 1735902 is being loaded.
# abbeville# 3038789 is being loaded.
# kushima# 1895695 is being loaded.
# aloleng# 1731298 is being loaded.
# ulaangom# 1515029 is being loaded.
# binga# 895057 is being loaded.
# urucara# 3385670 is being loaded.
# inhambane# 1045114 is being loaded.
# sisimiut# 3419842 is being loaded.
# verdun# 2969958 is being loaded.
# migori# 186731 is being loaded.
# boralday# 1526384 is being loaded.
# aswan# 359792 is being loaded.
# liverpool# 2644210 is being loaded.
# rudnyy# 1519843 is being loaded.
# port blair# 1259385 is being loaded.
# funadhoo# 1337620 is being loaded.
# kupang# 2057087 is being loaded.
# sechura# 3691954 is being loaded.
# artyk is not available.
# iqaluit# 5983720 is being loaded.
# thunder bay# 6166142 is being loaded.
# yanan is not available.
# dzhebariki-khaya# 2024626 is being loaded.
# karwar# 1267635 is being loaded.
# gunjur# 2413419 is being loaded.
# manaus# 3663517 is being loaded.
# requena# 2511930 is being loaded.
# beira# 3119841 is being loaded.
# Download complete!

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
WeatherDF.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  573.000000  5.730000e+02  573.000000  573.000000  573.000000
# mean    45.136126  1.541370e+09   80.902269   21.660454   15.733141
# std     35.274978  1.279365e+03   18.675295   33.109166   87.870718
# min      0.000000  1.541365e+09    8.000000  -54.810000 -179.170000
# 25%      5.000000  1.541369e+09   72.000000   -4.090000  -61.120000
# 50%     44.000000  1.541371e+09   87.000000   27.970000   17.600000
# 75%     76.000000  1.541371e+09   95.000000   50.100000   87.760000
# max    100.000000  1.541372e+09  100.000000   78.220000  179.320000
#
#          Max Temp  Wind Speed
# count  573.000000  573.000000
# mean    55.032266    7.796601
# std     23.549443    5.873143
# min    -29.108200    0.603973
# 25%     42.800000    3.355404
# 50%     59.000000    5.816034
# 75%     75.020000   10.670186
# max     89.600000   38.027917

# %%
WeatherDF.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Qaanaaq           0      GL  1541370948       100  77.48  -69.36
# 1       Cabimas          44      VE  1541370829        89  10.39  -71.44
# 2  Punta Arenas          40      CL  1541368800        57 -53.16  -70.91
# 3       Rikitea           8      PF  1541370949        99 -23.12 -134.97
# 4    Kota Belud          75      MY  1541368800        88   6.35  116.43
#
#    Max Temp  Wind Speed
# 0   -0.1282   11.117573
# 1   82.8068    2.729062
# 2   50.0000   20.803507
# 3   74.2568   20.065319
# 4   75.2000    5.816034

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(WeatherDF["Lat"], WeatherDF["Max Temp"], facecolors = "steelblue", edgecolors = "black", alpha = 0.75)

ChartDate = WeatherDF["Date"][0]
ChartDate = pd.to_datetime(ChartDate, unit='s').date()

plt.grid
plt.title("City Latitude vs Max Temperature (" + str(ChartDate.month) + "/" + str(ChartDate.day) + "/" + str(ChartDate.year) + ")")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")

plt.savefig("Temp_Scatter.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(WeatherDF["Lat"], WeatherDF["Humidity"], facecolors = "steelblue", edgecolors = "black", alpha = 0.75)

plt.grid
plt.title("City Latitude vs Humidity (" + str(ChartDate.month) + "/" + str(ChartDate.day) + "/" + str(ChartDate.year) + ")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

plt.savefig("Humidity_Scatter.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(WeatherDF["Lat"], WeatherDF["Cloudiness"], facecolors = "steelblue", edgecolors = "black", alpha = 0.75)

plt.grid
plt.title("City Latitude vs Humidity (" + str(ChartDate.month) + "/" + str(ChartDate.day) + "/" + str(ChartDate.year) + ")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

plt.savefig("Cloud_Scatter.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(WeatherDF["Lat"], WeatherDF["Wind Speed"], facecolors = "steelblue", edgecolors = "black", alpha = 0.75)

plt.grid
plt.title("City Latitude vs Wind Speed (" + str(ChartDate.month) + "/" + str(ChartDate.day) + "/" + str(ChartDate.year) + ")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

plt.savefig("Wind_Scatter.png")
